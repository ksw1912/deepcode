# %%
import numpy as np

# %%
paths = [
    r"C:\Users\KimSeowon\Desktop\kimseowon_Research\CounterPart_Model\train\FECDNet\FECDNet_fakeV_b8_lr0.0001\best_checkpoint_epoch_57.pth",
    r"C:\Users\KimSeowon\Desktop\kimseowon_Research\CounterPart_Model\train\FECDNet\FECDNet_fakeV_b8_lr0.0001_2\best_checkpoint_epoch_63.pth",
    r"C:\Users\KimSeowon\Desktop\kimseowon_Research\CounterPart_Model\train\FECDNet\FECDNet_fakeV_b8_lr0_4\best_checkpoint_epoch_92.pth",
    r"C:\Users\KimSeowon\Desktop\kimseowon_Research\CounterPart_Model\train\FECDNet\FECDNet_fakeV_b8_lr0_5\best_checkpoint_epoch_92.pth",
    r"C:\Users\KimSeowon\Desktop\kimseowon_Research\CounterPart_Model\train\FECDNet\FECDNet_fakeV_b8_lr0_6\best_checkpoint_epoch_92.pth",
    r"C:\Users\KimSeowon\Desktop\kimseowon_Research\CounterPart_Model\train\FECDNet\FECDNet_fakeV_b8_lr0_7\best_checkpoint_epoch_40.pth",
    r"C:\Users\KimSeowon\Desktop\kimseowon_Research\CounterPart_Model\train\FECDNet\FECDNet_fakeV_b8_lr0_8\best_checkpoint_epoch_40.pth",
    r"C:\Users\KimSeowon\Desktop\kimseowon_Research\CounterPart_Model\train\FECDNet\FECDNet_fakeV_b8_lr0_9\best_checkpoint_epoch_74.pth",
    r"C:\Users\KimSeowon\Desktop\kimseowon_Research\CounterPart_Model\train\FECDNet\FECDNet_fakeV_b8_lr0_10\best_checkpoint_epoch_74.pth",
]

seg_mf1 = [0.8874, 0.8860, 0.8887, 0.8867, 0.8796, 0.8866, 0.8885, 0.8913, 0.8913]
seg_miou = [0.8064, 0.8045, 0.8080, 0.8053, 0.7952, 0.8053, 0.8081, 0.8123, 0.8123]
seg_oa = [0.9410, 0.9410, 0.9399, 0.9410, 0.9390, 0.9408, 0.9421, 0.9435, 0.9435]

# %%
print(np.mean(seg_mf1),np.std(seg_mf1))
print(np.mean(seg_miou),np.std(seg_miou))
print(np.mean(seg_oa),np.std(seg_oa))
# Out:
# 0.8873444444444444 0.003286710990610878
# 0.8063777777777779 0.004790448315317517
# 0.9413111111111111 0.001417701147354387
