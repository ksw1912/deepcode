# %%
import numpy as np

# %%
seg_mf1 = [
    0.9480,
    0.9453,
    0.9453,
    0.9469,
    0.9464,
    0.9467,
    0.9487,
    0.9476,
    0.9498,
    0.9492
]

seg_miou = [
    0.9030,
    0.8984,
    0.8984,
    0.9012,
    0.9003,
    0.9008,
    0.9044,
    0.9024,
    0.9063,
    0.9052
]

seg_oa = [
    0.9699,
    0.9683,
    0.9683,
    0.9692,
    0.9689,
    0.9691,
    0.9704,
    0.9697,
    0.9712,
    0.9706
]

# %%
print(np.mean(seg_mf1),np.std(seg_mf1))
print(np.mean(seg_miou),np.std(seg_miou))
print(np.mean(seg_oa),np.std(seg_oa))
# Out:
# 0.9473899999999998 0.001471359915180502
# 0.9020400000000001 0.002579224689708134
# 0.9695599999999999 0.0009254188241007304
