# %%
import numpy

# %%
f1_list = [
0.9565,
0.9556,
0.9581,
0.9598,
0.9598,
0.9584,
0.9596,
0.9592,
0.9592
]
oa_list = [
0.9755,
0.9749,
0.9765,
0.9774,
0.9774,
0.9767,
0.9772,
0.9770,
0.9770
]

# %%
miou_list = [
0.9181,
0.9165,
0.9209,
0.9240,
0.9240,
0.9215,
0.9235,
0.9229,
0.9229
]

# %%
import numpy as np

f1 = np.array(f1_list)
miou = np.array(miou_list)

print(f1.mean(), f1.var(), f1.std())
print(miou.mean(), miou.var(), miou.std())
# Out:
# 0.9584666666666668 2.01555555555556e-06 0.0014197026292697918
# 0.9215888888888889 6.363209876543275e-06 0.0025225403617272955
